# %%
####### Assignment: Text Adventure Game #######
#
# Author: Dalton Lee Everett
# 
# Note for graders: i went a little overborn with the length and did not 
#                   realize until i was wrapping it up.
#
#
#
#Game title: The Dragonborn, A Skyrim Story
#
# Skyrim is a fantasy roleplay video game that has turned out an array of books,
# short films, and art forms. In this game, you start as a prisonner that is
# blessed by a dragon who freed him and mysteriously disappeared
# 
# This game is about accumulating points through your characters journey. 
# At the end, the points you accumulated will then give you a destiny title
# (i.e. king, knight) that fits your characters respective points. 
# You accumulate points by the selection of your dialgue you choose, luck,
# winning a duel, and lastly defeating a dragon at the end. 
# 
# 
# There are multiple main parts of this game
# - Introduction, clicking any key
# - Location 1 or 2
#    - 1 You will go through binary diologue and a duel
#   - 2 You will either die or run back to step 1, making you go to college
# - Fight against dragon
# - Title is given
#
# Have Fun!


import random
from random import randint

#welcoming in the user
print("Welcome! Before starting your journey  lets create your character:")

#gathering the name of character
character_name = input("What is your characters name? ")
character_name_upper = character_name.upper()
character_score = [0]


#this is the first stage of the character journey
#this will serve as an introduction to the storytelling of the rest of the game

def start_game():
############################## BEGIN Dialoge ##################################
    print(f"""
-------------------------------------------------------
-------------------- Morning DAY 1 --------------------
-------------------------------------------------------
\n{character_name} begins to open their eyes to a bright sunny day.

The cart rattles along the road, bouncing and creaking as the horses pull it forward\
.\nThe prisoner, a young man, sits in shackles, \
\nlooking out at the rolling hills and forests of the land of Skyrim.

    GUARD
(grunting)
Nearly there, prisoner. And then it's straight to the chopping block.

    {character_name_upper}
(under his breath)
Not if I can help it.
    
The prisoner looks around, searching for a way out. Suddenly, a dragon roars overhead,\
\nits shadow passing over the cart. The prisoner looks up, stunned, \
\nas the dragon circles and lands on the road ahead.

    DRAGON
(roaring)
Skyrim belongs to the dragons!
    
The dragon attacks the cart, blasting it with fire and tearing it apart.\
\n{character_name_upper} is thrown clear, landing on the road, struggling to stand, \
\nlooking up at the dragon as it flies off into the distance.
    
    {character_name_upper}
(whispering)
What have I done to deserve this?
    
The scene ends as the prisoner sets out to find the answers he seeks, \
\nand to claim his place in the land of Skyrim.
    
\n{character_name_upper} sets out towards Whiterun""")
    
    
    input("""
    ************************
    ** Press enter to hike *
    *** towards Whiterun ***
    ************************
    """)
    
    
    stage_1()


#this first stage is to set the game up and decide the next path that the user will go to
def stage_1():
    print(f"""{character_name} has arrived to Whiterun!
    
After the long trek through the relm you head towards the tavern for mead and 
needed rest.""")
    
    
    input("""
    ************************
    ** Press enter to walk *
    **** towards tavern ****
    ************************
    """)
    
    
    print("""\nYou overhear some gaurds talking about the many different realms of the land \
\npotential paths to take. You hear of theifs who move as quiet as the wind \
\nand as rich as the kings. Great warrios who can defeat a giant alone with \
\nbut their battle axes. Wizards who can summon healing potions and poisons.\
\nGreat merchants with luxorius artifacts and stories that come along with them.\


\nYou decide that you need rest, and head to sleep in the barn.""")
    
    
    input("""
    ************************
    *** Press to stumble ***
    ****** to the barn *****
    ************************
    """)
    print(f"""
    {character_name_upper}
(drunkingly)
Ahhhh, grreeaaaatt. This haystack looks perfect.

Your character passes out in the barn with no regard to health or hygine
-------------------------------------------------------
---------------------- END DAY 1 ----------------------
-------------------------------------------------------""")

    input("""
    ************************
    ** Press to wake from **
    ****** deep sleep ******
    ************************
    """)
    print(f"""
-------------------------------------------------------
-------------------- Morning DAY 1 --------------------
-------------------------------------------------------

    {character_name_upper}
Such a great day to become a new person. And just like everyone else in
my society I have the lush career choices of becoming a scholar or pillager.
Oh the places I'll go.

Now, the choice is yours. Which of the following will you become after listening\
to people at the tavern?
    \nChoose one of the following Cities:
1. Winterhold, The great university known for their science breakthroughs (score: 5 points)
2. Windhelm, Battle hardened society and strong history  (score: 7 points)""")
################################# END Dialoge #################################

    choice = int(input("Where do you go? (1-2): "))

#location posibilites that each have their own specific role
#there is no location more powerful than the other. They all follow
#the same scoring, but a different journey    
    try:
        if choice == 1:
            winterhold()
        elif choice == 2:
            windhelm()
################################################################################         
    #I was very ambitious in the beginning with my plan with more locations
    #skyrim lore is too deep
    #I am keeping it here however because it is a reminder of what i will make
    #and i will continue to build on this
        elif choice == 3:
            raise ValueError
            solitude()
        elif choice == 4:
            raise ValueError
            riften()
################################################################################        
        else:
            raise ValueError
    except ValueError:
        print("Invalid input, please follow directions. Restart at checkpoint.")
        return stage_1()
    
#Winterhold is a college known for its magice
#There are 3 stages:
#1 You meet arch-mage and you tell him your intentions
#2 You are in class and have the opportunity to lie or be honest
#  Lie, gives you the chance to get more XP but can take away XP
#  Honest, gives you some XP but not as much as if you lie and right
#3 You fight a classmate 'Orgith' in a duel
#  the duel follows a rock, paper, scissor pattern of playing
def winterhold():
    global character_score  
    character_score[0] += 5
    
############################## BEGIN Dialoge ##################################
    print(f"""
{character_name} sets out to Winterhold in the brisk early hours

-------------------------------------------------------
------------------- Afternoon Day 2 -------------------
-------------------------------------------------------
    """)
    input("""
    ************************
    **** Press to arrive ***
    ***** in WinterHold ****
    ************************
    """)
    print(f"""
{character_name} begins to walk through the door, making their way down\
\nthe loosly lit, cold, and lonely coddlestone hallway. Suddenly,\
\na voice comes from behind you.""")
    input("""
    ************************
    ***** Press enter ******
    **** to turn around ****
    ************************
    """)
    print("""
    ARCH-MAGE
(loudly)
Hello weary travelor, nice meet you! I am dean We are always seeking new students and \
\ntravelors alike! Don't let the rumors of these walls scare you, Yes Yes, these walls\
\nwere formed out of magic itself, but dont let that dampen your time here and\
\njourney of academia!""")
    print("-"*20)


    #this to see what the player intentions
    #both will give XP but the perferred answer will give more
    print("""\nHow do you respond, what is it you seek? (learn/explore)
    
    1. Learner, "I seek to learn magic and the responsibilites that come with it"
    2. Explorer, "I want to know the power and value that magic has"
    """)
################################# END Dialoge #################################

    q1 = input("\nHow do you respond? (1-2)")
    
    #Learner, gives you 8 points and a positive response    
    try:  
        if q1 == "1":
            character_score[0] += 8
            print("-"*20)
            print(f"""
    ARCH-MAGE
(excitingly)   
Great great, Nice to meet you {character_name}! I am always excited to hear of\
\nnew students. Quick, now lets head to your class!""")
            input("""
    ************************
    **** Press enter to ****
    ***** go to class ******
    ************************
    """)
    
    #Exploreer, give you 4 points and a moderate response
        elif q1 == "2":
            character_score[0] += 4
            print("-"*20)
            print(f"""
    ARCH-MAGE    
(unethusiasticly)
Oh okay okay, thats good! Well i hope you enjoy your time here {character_name}\
\nand we have a class starting up if you are wanting to peek your head in and learn\
\n\nYou may end up sticking around after a class!""")
            input("""
    ************************
    **** Press enter to ****
    ***** go to class ******
    ************************
    """)
        else:
            raise ValueError
    except ValueError:
        print("Invalid input, please follow directions. Restart at checkpoint.")
        return winterhold()

    
    #this is a classroom scene, where you are not aware and get caught
    #You can either Lie or Be Humble
    #Lying successfully gives you the opportunity to get +10 xp (-10 if unsucessful)
    #Being humble will give you a gaurenteed 4 points
    print(f"""\n
Sitting in the back of the classroom you notice attempt to maintain focus.\
\nThe classroom is more of a labratory, and not a clean one. Cobwebs are so large\
\nthat you see the spiders preparing their meals, vials have liquid spurting out\
\n, and animals of all kinds of creatures in vials . . . you notice a dragon

    TEACHER
(pointing directly at you)
{character_name_upper}! What is the answer to the question? Were you listening,\
\nor are you still going to continue being distracted?
    
    {character_name_upper}
(confidently)
1. Lie, "Yes, I was listening"
2. Admit, "My mind was elsewhere, I will fix the problem."
""")
    
    #If you lie you will be asked a second question by the teacher
    # you will select 1 or 2 and the computer will randomize the 1 or 2
    # if you have the same value then you succeeded in your lie + 10 XP
    # if you fail in your lie you -10 XP
    q2 = input("\nWhat do you do? (1-2) ")
    if q2 == "1":
        print("-"*20)
        print("""
    TEACHER
Okay, what is the answer?""")
        q2_a = input("Take a guess (1-2)")
        print("-"*20)
        random_number = random.randint(1,2)
        #teacher will praise you for your correct answer
        if q2_a == str(random_number):
            character_score[0] +=10
            print(f"""
    TEACHER
Goodjob, that was a wonderful answer {character_name}. With an answer like that\
\nyou may become the next Arch-Mage

+10 XP for successful lie""")
        #the teacher will laugh at you if you cheat    
        else:
            character_score[0] -=10
            print("""
    TEACHER
(laughing)
Liar

-10 XP for failure to lie""")
            

    #If you are humble
    #You will get + 4 XP and an annoyed response from the teacher
    #this will not have the random option the "lie" has
    elif q2 == "2":
        character_score[0] += 4
        print("-"*20)
        print(f"""
    TEACHER
(annoyed)
Okay {character_name}, thank you for telling the true. Now, start paying attention.

+4 XP for telling the truth, but you were annoying the teacher""")
    else:
        stage_1()
    
    #update the character score so you can see what you have
    #also end of the day, but not the functions
    print(f"""
--------------------------------------------------
{character_name} has, {character_score}, XP points    
--------------------------------------------------
------------------ END DAY 1 ---------------------
--------------------------------------------------""")
    input("""
    ************************
    **** Press enter to ****
    **** begin next day ****
    ************************
    """)

    #this is the second part
    #here you will duel your class mate in a rock, paper, sciccors type of game
    #best out of 3 rounds will win the game
    #this is the introduction part
    

############################## BEGIN Dialoge ##################################
    print(f"""
--------------------------------------------------
---------------- Four weeks later ----------------
--------------------------------------------------

Weeks have gone by and {character_name} has decided to stay to learn and\
\nhave a better understanding of magic.

Today is a day many students have been looking forward to. The Day of Testing,\
\nwhich pairs students up against each other""")  
    input("""
    ************************
    ***** Press enter ******
    ***** to continue ******
    ************************
    """)
    print(f"""
    ARCH-MAGE
Next up, {character_name} vs Orgith! Contestants please back up into corners\
\nand get ready to fight. you know the deal, three rounds. Give it all you got.

The crowd in the food hall is defeaning and overwhelimg,\
\nuntil you see your opponent

    ORGITH
{character_name} you loosed lip outsider, coming in here and taking our knowledge\
\nof magic! You dont deserve what we have!

Your anger is building up and you are ready to attack. You have your magic charged\
\nand your shot aligned.
    
    ARCH-MAGE
(screaming)
FIGHT!""")
    input("""
    ************************
    **** Press enter to ****
    ***** begin fight ******
    ************************
    """)
    print(f"""
    
    ORGITH
(sinisterly)
{character_name} im going to destroy you!
    """)
################################# END Dialoge #################################

    print("-"*50)
    
#the game begins
#If you lose you will not die. You will continue because this is a duel, not death duel
#Win, +20 XP for winning
#Lose, -20 XP
#Tie, +10 XP for not losing
    rounds = 0
    user_points = 0
    orgiths_points = 0
    
    #The game will loop for 3 rounds and then a final winner is decided
    #it is not a death match, just a duel, so if you lose you only lose XP
    while rounds < 3:
        rounds += 1
        print(f"""\nRound: {rounds}
        
        User Points:    {user_points}
        Orgiths Points: {orgiths_points}""")
        character_choice = input("""
    What is your move?
    
    1. Attack
    2. Defend
    3. Heal
    
    Enter (1-3): """)
        
        #orgith has no strategy, just going random everytime, so guessing is best
        orgith_choice = random.choice(["1", "2", "3"])


            
        #So i used the dragon fight (you can see later in the game), but instead
        #of a health bar i used a points system. It is better than rock, paper,
        #sciccors because the scoring makes sense if you were to defend or heal
        if character_choice == orgith_choice:
            orgiths_points += 1
            user_points += 1
            print("Both of your moves countered each other, no one takes damage!")
            print("-"*20)
            
        elif character_choice == "1" and orgith_choice == "2":
            orgiths_points -= 1
            user_points += 1
            print("You hit Orgith when it was defending!")
            print("-"*20)
            
        elif character_choice == "1" and orgith_choice == "3":
            orgiths_points -= 2
            user_points += 2
            print("Critical Hit! Orgith was hit in a vulnerable spot!")
            print("-"*20)
            
        elif character_choice == "2" and orgith_choice == "1":
            orgiths_points += 1
            user_points -= 1
            print("You were hit as you were defending!")
            print("-"*20)
            
        elif character_choice == "2" and orgith_choice == "3":
            orgiths_points += 2
            print("Orgith was able to heal while you were defending!")
            print("-"*20)
                        
        elif character_choice == "3" and orgith_choice == "1":
            orgiths_points += 2
            user_points -= 2
            print("Orgith critial hit on you! You were ungaurded!")
            print("-"*20)
                        
        elif character_choice == "3" and orgith_choice == "2":
            user_points += 2
            print("You were able to heal while Orgith was defending!")
            print("-"*20)
    print(f"""Round: Final  
        
        User Points:    {user_points}
        Orgiths Points: {orgiths_points}
        """)        
    
    print("""
    ARCH-MAGE
(yelling)
Game over!
""")
    
    #Win, the arch-mage is very excited
    #He will praise you and give you 20 XP
    if user_points > orgiths_points:
        print(f"""   
    CROWD
(cheering excitiable)

    ARCH-MAGE
(excitingly)
{character_name} wins the game! Great job {character_name}, I knew big things\
\nwere going to come of you, and you still shocked us all

\n'You will game +20xp for your win.'""")
        character_score[0] += 20
        
    #Lose, the arch-mage is very disappointed
    #He will give you a shunning comment
    elif orgiths_points > user_points:
        print(f"""
    CROWD
(Jeering and hollaring)

    ARCH-MAGE
(shockingly)
Orgith wins the game! I am disappointed in you {character_name}. We had \
\nhigh hopes for you. I guess they were for nothing.

\n'You will lose 10 xp becuase of your loss.'""")
        character_score[0] -= 10
        
    #Tie, arch-mage is annoyed that you wasted everyones time
    #He is bored and not wanting t
    else:
        print(f"""
    CROWD
(booing and yelling at both oponents)

    ARCH-MAGE
(annoyed)
That was boring, you both stick. Somebody hit somebody. The game is a draw. \

\n'You will lose 5xp for your draw.'""")
        character_score[0] -= 5
        
    print(f"""
--------------------------------------------------
{character_name} currently has {character_score} 
--------------------------------------------------


{character_name} decides to stay for an unknown time
----------------------------------------------------
""")
    input("""
    ************************
    **** Press enter to ****
    *** continue journey ***
    ************************
    """)
    stage_3()
    
    
    
    
#I had a lot of ambition with this seciton and was going to make it just like
#winterhold, but its own adventure, inestead, i ran out of time and had to be
#concious of your time
def windhelm():
    global character_score
    
    q1 = input(f"""
------------------------------------------
{character_name} make its way to Windhelm
------------------------------------------
    
A fellow travelor is on this path.
    
    {character_name_upper}
(excitingly)
Hellow fellow travelor!

    Travelor
(unsheathes sword)
Give me all your possessions. I've killed smarter, stronger, and braver than you
----------------------
    What do you do?
    
    1. Fight
    2. Run
    
    Enter (1-2): """)
    
    #If the user decides to fight
    #i want to come back and have a "level" so you can gain XP and have
    #the opportunity to beat the raider, but now you have low XP and need
    #to level up before passing this stage
    #Do not attempt to get high XP and come back because i made this section
    #so you are forced to use Winterhold to succeed in the game
    if q1 == "1":
        print("-"*20)
        print(f"""
    RAIDER
(menacingly)
You'll be begging for mercy before I'm through with you

The raider sliced n' diced you
            """)
        input("""
    ************************
    **** Press enter to ****
    ****** checkpoint ******
    ************************
    """)
        return stage_1()
    
    #If the user decides to run then the character will
    #will go back to the checkpoint at whiterun
    else: 
        print("-"*20)
        print(f"""
    RAIDER
(standing over {character_name})

You call yourself a warrior? Ha! You couldn't fight your way out of a wet paper bag!!

You continue to run until you reach back to where you came""")
        input("""
    ************************
    **** Press enter to ****
    ****** checkpoint ******
    ************************
    """)
        return stage_1()
        
    
    
    q2 = input("Is fire warm? (yes/no) ")
    if q2 == 2:
        points += random.randint(1, 10)
    stage_3()
    

    
#Lets mess up that dragon
#1 You defeat the dragon and win XP
#2 The dragon kills you
#3 You run away and forfeit the opportunity
def stage_3():
    print(f"""
--------------------------------------------------
------------------- DAY 458 ----------------------
--------------------------------------------------   

As the days fly by they start to blend and you start to remember how many\ 
\ndays you have been working on your new life direction, and the craziness\
\nthat brought you here

    {character_name_upper}
(thinking to themselves)
If it wasnt for that dragon who helped me escape, i wouldnt be here.\
\nI have always wondered why he did it. Did he want me to train it, tame it,\
\n learn from it?

You continue to think of the beautiful ground that surrounds you, and the beautiful\
\nland you are able to call home. Sun shining down, nice fluffy clouds in the sky,\
\nand a slight breeze takes your mind to the days when you were a youngling and\
\ndreamt of dragons""")
    input("""
    ************************
    **** Press enter to ****
    ****** day dream *******
    ************************
    """)
    
    #The user gets to decide if they want to play\
    play_or_not = input(f"""

    {character_name_upper}
(outloud)
pppsssttt, that dragon probably doesnt even know how to fly anymore. Always hiding\
\nin their caves, too greedy to meet anyone, and too selfish to . . .

The Sky darkens around you and a thunderous roars comes from the mountain near!\
\nYou see a bird like figure swooping down from the dark storm clouds.\
\n\nComing diretly towards you
\nThe figure has broke the clouds and it reveals it is a dragon!

    DRAGON
(god-like)
YOUUUUUUU, I've been waiting for you. I have been waiting centurys for a wrothy\
\nopponent.

(hissing)
Nooooowwwwwwww

(roaring)
Its my time to kill you!



What will you do?

1. Fight
2. Run""")
    
    #this is the condition that leads to if you are or arent playing
    if play_or_not == "1":
        play_game()
    else:
        end_game()
        print(f"""You're a baby for running away from the dragon.""")
        
#Players have the opportunity to earn or lose 60 XP points if they win  or lose
def play_game():
    global character_score
    #we need to initiate the health bar of the game
    character_health = 100
    computer_health = 100
    
    
    #this is a loop that has the dragon vs the player. this will go until
    #one of the characters health bars drops below 0.
    while character_health > 0 and computer_health > 0:
        print(f"\nYour health: {character_health}")
        print(f"Computer health: {computer_health}")
        
        print("\nChoose your weapon:")
        print("1. Attack")
        print("2. Defend")
        print("3. Heal")
        character_choice = input()
        dragon_choice = str(randint(1,3))
        
        print(f"\nYou chose {character_choice}")
        print(f"The computer chose {dragon_choice}")
        
        #Below is the scoring per hits. This is much like the one before but
        #the scoring is instead a health bar that goes down or up
        if character_choice == dragon_choice:
            print("Both of your moves countered each other, no one takes damage!")
            print("-"*20)
        elif character_choice == "1" and dragon_choice == "2":
            print("You hit the dragon when it was defending!")
            print("-"*20)
            computer_health -= 15
        elif character_choice == "1" and dragon_choice == "3":
            print("Critical Hit! Dragon was hit in a vulnerable spot!")
            print("-"*20)
            computer_health -= 25
        elif character_choice == "2" and dragon_choice == "1":
            print("You were hit as you were defending!")
            print("-"*20)
            character_health -= 15
        elif character_choice == "2" and dragon_choice == "3":
            print("The dragon was able to heal while you were defending!")
            print("-"*20)
            computer_health += 10
        elif character_choice == "3" and dragon_choice == "1":
            print("Dragon critial hit on you! You were ungaurded!")
            print("-"*20)
            character_health -= 15
        elif character_choice == "3" and dragon_choice == "2":
            print("You were able to heal while the dragon was defending!")
            print("-"*20)
            character_health += 10
            
        #below is once the dragon or user health is less than 0
        #it will show if you are the winner or loser   
        if character_health <= 0:
            character_score[0] -=60
            print(f""" The dragon killed {character_name}.""")
            play_game()
        elif computer_health <= 0:
            character_score[0] += 60
            print(f"""
--------------------------------------------------------------    
Congradulations! {character_name} killed the dragon.
--------------------------------------------------------------
    
    ------------------- +100 XP -------------------

The lands of Skyrim are applauding all through every Kingsom!

    TOWNS-PEOPLE
(a mix matching crowd of knights, drunks, beggars, and royalty)

All hail the Dragonborn!

The true king!

My Jarl!            
            """)
    input("""
    ************************
    **** Press enter to ****
    *** see your destiny ***
    ************************
    """)
    end_game()
                
#this is the end-scoring part of the game
#there are ranges of points that if you are to get within will give you
def end_game():
    global character_score
    print(f"{character_name} has, {character_score}, XP")
    print(f"""
    {character_name_upper}
(humbely)
I did my best while i was here and I am excited to see my mark 
--------------------------------------------------------------
    """)
    #the highest achievement in skyrim
    if character_score[0] >= 70:
        print(f"""
        
        Love Live the King!
        
THE HIGH KING {character_name}, OF SKYRIM
        
        """)
    #A very humble and leading position
    elif character_score[0] >= 65:
        print(f"""
        
        To our Leader!
        
{character_name}, JARL OF Whiterun
        
        """)
    #a fighting person
    elif character_score[0] >= 40:
        print(f"""
        
        To the fierce!
        
    Knight {character_name}
        
        """)
    #Low XP
    elif character_score[0] >= 1:
        print(f"""
        
        Who is this guy?
        
{character_name}, you're a peasent that probably plows a field survival, but\ 
\ngives all their food to the kingdom under the guise of pRoTeCtIiOn
 
 lol
        """)
    #somehow has negative XP
    elif character_score[0] <= 0:
        print(f"""1
        
        Why did you even try
        
Yeah, {character_name}, you are 100% going to end up as a low life panhadler\
\nif you're not snatched up by the Dark Brotherhood
        
        
Ya bum""")


        if __name__ == "__main__":
            start_game()
start_game()
# Out:
# Welcome! Before starting your journey  lets create your character:
# What is your characters name? MadRass
#
# -------------------------------------------------------
# -------------------- Morning DAY 1 --------------------
# -------------------------------------------------------
#
# MadRass begins to open their eyes to a bright sunny day.
#
# The cart rattles along the road, bouncing and creaking as the horses pull it forward.
# The prisoner, a young man, sits in shackles,
# looking out at the rolling hills and forests of the land of Skyrim.
#
#     GUARD
# (grunting)
# Nearly there, prisoner. And then it's straight to the chopping block.
#
#     MADRASS
# (under his breath)
# Not if I can help it.
#
# The prisoner looks around, searching for a way out. Suddenly, a dragon roars overhead,
# its shadow passing over the cart. The prisoner looks up, stunned,
# as the dragon circles and lands on the road ahead.
#
#     DRAGON
# (roaring)
# Skyrim belongs to the dragons!
#
# ...
